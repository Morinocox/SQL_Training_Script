-- %% [markdown]
-- # [resume01]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [resume01]    Script Date: 7/21/2022 17:26:00 ******/
CREATE DATABASE [resume01]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'resume01', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\resume01.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'resume01_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\resume01_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [resume01] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [resume01].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [resume01] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [resume01] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [resume01] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [resume01] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [resume01] SET ARITHABORT OFF 
GO
ALTER DATABASE [resume01] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [resume01] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [resume01] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [resume01] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [resume01] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [resume01] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [resume01] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [resume01] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [resume01] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [resume01] SET  ENABLE_BROKER 
GO
ALTER DATABASE [resume01] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [resume01] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [resume01] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [resume01] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [resume01] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [resume01] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [resume01] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [resume01] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [resume01] SET  MULTI_USER 
GO
ALTER DATABASE [resume01] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [resume01] SET DB_CHAINING OFF 
GO
ALTER DATABASE [resume01] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [resume01] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [resume01] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [resume01] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [resume01] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[east_or_west]

-- %%
USE [resume01]
GO

-- %%
/****** Object:  UserDefinedFunction [dbo].[east_or_west]    Script Date: 7/21/2022 17:26:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE FUNCTION [dbo].[east_or_west] (
	@long DECIMAL(9,6)
)
RETURNS CHAR(4) AS
BEGIN
	DECLARE @return_value CHAR(4);
	SET @return_value = 'same';
    IF (@long > 0.00) SET @return_value = 'east';
    IF (@long < 0.00) SET @return_value = 'west';
 
    RETURN @return_value
END;
GO

-- %% [markdown]
-- # [dbo].[f_check_string]

-- %%
/****** Object:  UserDefinedFunction [dbo].[f_check_string]    Script Date: 7/21/2022 17:26:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
/*returns 1 if input string is OK, 0 otherwise*/
CREATE FUNCTION [dbo].[f_check_string] (@string VARCHAR(MAX)) RETURNS INT AS BEGIN
    DECLARE @ret_val INT;
    SET @ret_val=1;
    IF (@string like '%''%') SET @ret_val=0
    ELSE IF (@string like '%--%') SET @ret_val=0
    ELSE IF (@string like '%/*%') SET @ret_val=0
    ELSE IF (@string like '%*/%') SET @ret_val=0
    ELSE IF (@string like '%@') SET @ret_val=0
    ELSE IF (@string like '%@@%') SET @ret_val=0
    ELSE IF (@string like '%char%') SET @ret_val=0
    ELSE IF (@string like '%nchar%') SET @ret_val=0
    ELSE IF (@string like '%varchar%') SET @ret_val=0
    ELSE IF (@string like '%nvarchar%') SET @ret_val=0
    
    ELSE IF (@string like '%select%') SET @ret_val=0
    ELSE IF (@string like '%insert%') SET @ret_val=0
    ELSE IF (@string like '%update%') SET @ret_val=0
    ELSE IF (@string like '%delete%') SET @ret_val=0
    ELSE IF (@string like '%from%') SET @ret_val=0
    ELSE IF (@string like '%table%') SET @ret_val=0
 
    ELSE IF (@string like '%drop%') SET @ret_val=0
    ELSE IF (@string like '%create%') SET @ret_val=0
    ELSE IF (@string like '%alter%') SET @ret_val=0
 
    ELSE IF (@string like '%begin%') SET @ret_val=0
    ELSE IF (@string like '%end%') SET @ret_val=0
 
    ELSE IF (@string like '%grant%') SET @ret_val=0
    ELSE IF (@string like '%deny%') SET @ret_val=0
 
    ELSE IF (@string like '%exec%') SET @ret_val=0
    ELSE IF (@string like '%sp_%') SET @ret_val=0
    ELSE IF (@string like '%xp_%') SET @ret_val=0
 
    ELSE IF (@string like '%cursor%') SET @ret_val=0
    ELSE IF (@string like '%fetch%') SET @ret_val=0
 
    ELSE IF (@string like '%kill%') SET @ret_val=0
    ELSE IF (@string like '%open%') SET @ret_val=0
 
    ELSE IF (@string like '%sysobjects%') SET @ret_val=0
    ELSE IF (@string like '%syscolumns%') SET @ret_val=0
    ELSE IF (@string like '%sys%') SET @ret_val=0;
 
    RETURN (@ret_val);
END;
GO

-- %% [markdown]
-- # [dbo].[city]

-- %%
/****** Object:  Table [dbo].[city]    Script Date: 7/21/2022 17:26:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[city](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[city_name] [char](128) NOT NULL,
	[lat] [decimal](9, 6) NOT NULL,
	[long] [decimal](9, 6) NOT NULL,
	[country_id] [int] NOT NULL,
 CONSTRAINT [city_pk] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[east_from_long]

-- %%
/****** Object:  UserDefinedFunction [dbo].[east_from_long]    Script Date: 7/21/2022 17:26:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE FUNCTION [dbo].[east_from_long] (
	@long DECIMAL(9,6)
)
RETURNS TABLE AS
RETURN
	SELECT *
	FROM city
	WHERE city.long > @long;
GO

-- %% [markdown]
-- # [dbo].[country]

-- %%
/****** Object:  Table [dbo].[country]    Script Date: 7/21/2022 17:26:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[country](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[country_name] [char](128) NOT NULL,
	[country_name_eng] [char](128) NOT NULL,
	[country_code] [char](8) NOT NULL,
 CONSTRAINT [country_pk] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [country_ak_1] UNIQUE NONCLUSTERED 
(
	[country_name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [country_ak_2] UNIQUE NONCLUSTERED 
(
	[country_name_eng] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [country_ak_3] UNIQUE NONCLUSTERED 
(
	[country_code] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[v_country_all]

-- %%
/****** Object:  View [dbo].[v_country_all]    Script Date: 7/21/2022 17:26:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE VIEW [dbo].[v_country_all] AS SELECT * FROM country;
GO

-- %% [markdown]
-- # [dbo].[call]

-- %%
/****** Object:  Table [dbo].[call]    Script Date: 7/21/2022 17:26:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[call](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[employee_id] [int] NOT NULL,
	[customer_id] [int] NOT NULL,
	[start_time] [datetime] NOT NULL,
	[end_time] [datetime] NULL,
	[call_outcome_id] [int] NULL,
 CONSTRAINT [call_pk] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [call_ak_1] UNIQUE NONCLUSTERED 
(
	[employee_id] ASC,
	[start_time] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[call_outcome]

-- %%
/****** Object:  Table [dbo].[call_outcome]    Script Date: 7/21/2022 17:26:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[call_outcome](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[outcome_text] [char](128) NOT NULL,
 CONSTRAINT [call_outcome_pk] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [call_outcome_ak_1] UNIQUE NONCLUSTERED 
(
	[outcome_text] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[customer]

-- %%
/****** Object:  Table [dbo].[customer]    Script Date: 7/21/2022 17:26:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[customer](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[customer_name] [varchar](255) NOT NULL,
	[city_id] [int] NOT NULL,
	[customer_address] [varchar](255) NOT NULL,
	[next_call_date] [date] NULL,
	[ts_inserted] [datetime] NOT NULL,
 CONSTRAINT [customer_pk] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[customer_backup]

-- %%
/****** Object:  Table [dbo].[customer_backup]    Script Date: 7/21/2022 17:26:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[customer_backup](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[customer_name] [varchar](255) NOT NULL,
	[city_id] [int] NOT NULL,
	[customer_address] [varchar](255) NOT NULL,
	[next_call_date] [date] NULL,
	[ts_inserted] [datetime] NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[employee]

-- %%
/****** Object:  Table [dbo].[employee]    Script Date: 7/21/2022 17:26:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[employee](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[first_name] [varchar](255) NOT NULL,
	[last_name] [varchar](255) NOT NULL,
 CONSTRAINT [employee_pk] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [call_call_outcome]

-- %%
ALTER TABLE [dbo].[call]  WITH CHECK ADD  CONSTRAINT [call_call_outcome] FOREIGN KEY([call_outcome_id])
REFERENCES [dbo].[call_outcome] ([id])
GO
ALTER TABLE [dbo].[call] CHECK CONSTRAINT [call_call_outcome]
GO

-- %% [markdown]
-- # [call_customer]

-- %%
ALTER TABLE [dbo].[call]  WITH CHECK ADD  CONSTRAINT [call_customer] FOREIGN KEY([customer_id])
REFERENCES [dbo].[customer] ([id])
GO
ALTER TABLE [dbo].[call] CHECK CONSTRAINT [call_customer]
GO

-- %% [markdown]
-- # [call_employee]

-- %%
ALTER TABLE [dbo].[call]  WITH CHECK ADD  CONSTRAINT [call_employee] FOREIGN KEY([employee_id])
REFERENCES [dbo].[employee] ([id])
GO
ALTER TABLE [dbo].[call] CHECK CONSTRAINT [call_employee]
GO

-- %% [markdown]
-- # [city_country]

-- %%
ALTER TABLE [dbo].[city]  WITH CHECK ADD  CONSTRAINT [city_country] FOREIGN KEY([country_id])
REFERENCES [dbo].[country] ([id])
GO
ALTER TABLE [dbo].[city] CHECK CONSTRAINT [city_country]
GO

-- %% [markdown]
-- # [customer_city]

-- %%
ALTER TABLE [dbo].[customer]  WITH CHECK ADD  CONSTRAINT [customer_city] FOREIGN KEY([city_id])
REFERENCES [dbo].[city] ([id])
GO
ALTER TABLE [dbo].[customer] CHECK CONSTRAINT [customer_city]
GO

-- %% [markdown]
-- # [dbo].[p_customer]

-- %%
/****** Object:  StoredProcedure [dbo].[p_customer]    Script Date: 7/21/2022 17:26:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[p_customer] (@id INT)
-- procedure returns the entire row for the given id
AS BEGIN
  SELECT *
  FROM customer
  WHERE id = @id;
END;
GO

-- %% [markdown]
-- # [dbo].[p_customer_all]

-- %%
/****** Object:  StoredProcedure [dbo].[p_customer_all]    Script Date: 7/21/2022 17:26:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[p_customer_all]
-- procedure returns all rows from the customer table
AS BEGIN
  SELECT *
  FROM customer;
END;
GO

-- %% [markdown]
-- # [dbo].[p_customer_delete]

-- %%
/****** Object:  StoredProcedure [dbo].[p_customer_delete]    Script Date: 7/21/2022 17:26:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[p_customer_delete] (@id INT)
-- procedure deletes the row for the given id
AS BEGIN
  DELETE
  FROM customer
  WHERE id = @id;
END;
GO

-- %% [markdown]
-- # [dbo].[p_customer_insert]

-- %%
/****** Object:  StoredProcedure [dbo].[p_customer_insert]    Script Date: 7/21/2022 17:26:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[p_customer_insert] (@customer_name varchar(255), @city_id int, @customer_address varchar(255), @next_call_date date) AS
BEGIN
    IF (dbo.f_check_string (@customer_name) = 0 OR dbo.f_check_string (@customer_address) = 0)
        SELECT 'Input parameters were not OK.'
    ELSE BEGIN
        INSERT INTO customer(customer_name, city_id, customer_address, next_call_date, ts_inserted) VALUES(@customer_name, @city_id, @customer_address, @next_call_date, getdate());
        SELECT 'New row inserted.';
    END
END;
GO

-- %% [markdown]
-- # [dbo].[p_dynamic_sql]

-- %%
/****** Object:  StoredProcedure [dbo].[p_dynamic_sql]    Script Date: 7/21/2022 17:26:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[p_dynamic_sql] (@employee_id INT, @customer_id INT) AS
BEGIN
    DECLARE 
        @sql NVARCHAR(MAX);
    SET @sql = N'SELECT * FROM call';
    IF (@employee_id IS NOT NULL OR @customer_id IS NOT NULL)
        SET @sql = @sql + N' WHERE';
    IF @employee_id IS NOT NULL BEGIN
        SET @sql = @sql + N' employee_id = ' + CAST(@employee_id AS CHAR(10));
        IF @customer_id IS NOT NULL SET @sql = @sql + N' AND ';
    END;
    IF @customer_id IS NOT NULL SET @sql = @sql + N' customer_id = ' + CAST(@customer_id AS CHAR(10));
    SELECT @sql AS query;
    EXEC sp_executesql @sql;
END;
GO

-- %% [markdown]
-- # [resume01]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [resume01] SET  READ_WRITE 
GO
